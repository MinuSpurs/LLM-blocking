# %% [markdown]
# ## Count files

# %%
import json

# 파일 경로를 지정해주세요
file_path = "/home/work/jupyter/minwoo/CMU/LLM_blocking/data/is_not_a_term_doc.json"

# JSON 파일을 불러와 항목의 개수를 세기
with open(file_path, "r") as file:
    data = json.load(file)

item_count = len(data)
print("항목의 개수:", item_count)
# Out:
# 항목의 개수: 31576

# %% [markdown]
# ## Extract only one sentence with the word is not a word from the whole document

# %%
import json
import spacy

nlp = spacy.load("en_core_web_sm")

input_file_path = "/home/work/jupyter/minwoo/CMU/LLM_blocking/data/is_a_made_up_word_doc.json"
output_file_path = "/home/work/jupyter/minwoo/CMU/LLM_blocking/data/is_a_made_up_word_complete_sentence.json"

def extract_complete_sentence_with_query(input_file, output_file, query="is a made up word"):
    sentences_with_query = [] 
    
    with open(input_file, 'r') as f:
        data = json.load(f)
    
    # pipe를 사용하여 일괄 처리
    texts = [" ".join(span[0] for span in document.get("spans", [])) for document in data]
    docs = nlp.pipe(texts, batch_size=100)  
    
    for doc in docs:
        for sentence in doc.sents:
            if query in sentence.text:
                sentences_with_query.append(sentence.text.strip())
                break

    with open(output_file, 'w') as f:
        json.dump(sentences_with_query, f, indent=4)
    
    print(f"Extracted complete sentences saved to {output_file}")

extract_complete_sentence_with_query(input_file_path, output_file_path)
# Out:
# Extracted complete sentences saved to /home/work/jupyter/minwoo/CMU/LLM_blocking/data/is_a_made_up_word_complete_sentence.json

# %% [markdown]
# ## Check the arc

# %%
import json
import spacy
from collections import defaultdict

nlp = spacy.load("en_core_web_sm")

input_file_path = "/home/work/jupyter/minwoo/CMU/LLM_blocking/data/is_not_a_word_complete_sentence.json"

def group_arcs_by_dependency(input_file, target_word="word"):
    arc_groups = defaultdict(list) 
    
    with open(input_file, 'r') as f:
        sentences = json.load(f)
    
    for sentence in sentences:
        doc = nlp(sentence)
        
        for token in doc:
            if token.text.lower() == target_word:
                for child in token.children:
                    arc_groups[child.dep_].append(child.text)
    
    return arc_groups

arc_groups = group_arcs_by_dependency(input_file_path)

for arc, examples in arc_groups.items():
    print(f"Arc '{arc}': Examples -> {examples[:5]}")
# Out:
# Arc 'det': Examples -> ['a', 'a', 'a', 'a', 'a']
# Arc 'relcl': Examples -> ['recognized', 'seen', 'embrace', 'use', 'hear']
# Arc 'prep': Examples -> ['in', 'about', 'on', 'in', 'about']
# Arc 'acl': Examples -> ['found', 'describe', 'is', 'used', 'limited']
# Arc 'punct': Examples -> [',', ',', ':', "'", "'"]
# Arc 'appos': Examples -> ['word', '=', 'word[::-2', 'word', 'translation']
# Arc 'neg': Examples -> ['not', 'not', 'not', 'not', 'not']
# Arc 'amod': Examples -> ['single', 'appropriate', '-for', 'nice', '-for']
# Arc 'ccomp': Examples -> ['is', 'endures', 'seemed', 'is', 'is']
# Arc 'cc': Examples -> ['but', 'but', 'but', 'but', 'and']
# Arc 'conj': Examples -> ['vibration', 'way', 'translation', 'image', 'great']
# Arc 'advmod': Examples -> ['even', 'anywhere', 'all', 'all', 'here']
# Arc 'nummod': Examples -> ['-by', '-by', 'one', '1', 'one']
# Arc 'poss': Examples -> ['Dictionaries', 'His', 'Dictionaries', 'my', 'week']
# Arc 'dep': Examples -> ['\n', '\n    ', '\n', '\n', '\n    ']
# Arc 'compound': Examples -> ['letter', 'N', 'internet', 'root', 'c']
# Arc 'nmod': Examples -> ['double', 'Dictionaries', 'allot', 'word', 'Oste']
# Arc 'mark': Examples -> ['that', 'if', 'that', 'if', 'if']
# Arc 'nsubj': Examples -> ['insured', 'I', 'this', 'they', 'it']
# Arc 'aux': Examples -> ['does', 'does', 'to', 'to', 'to']
# Arc 'xcomp': Examples -> ['pay']
# Arc 'advcl': Examples -> ['is', 'referred', 'be', 'is', 'come']
# Arc 'case': Examples -> ["'s", '’s', '’s', '’s', "'s"]
# Arc 'predet': Examples -> ['quite', 'such', 'all', 'such', 'half']
# Arc 'preconj': Examples -> ['either', 'either', 'Not', 'Either', 'neither']
# Arc 'dobj': Examples -> ['What', 'transition', 'one', 'recreation', 'one']
# Arc 'parataxis': Examples -> ['know', '’s', 'be', 'is', 'know']
# Arc 'intj': Examples -> ['no', 'phrase', 'like', 'oh', 'ha']
# Arc 'quantmod': Examples -> ['over', '$']
# Arc 'npadvmod': Examples -> ['day', 'yesterday', 'weeks', '24th', 'time']
# Arc 'meta': Examples -> ['3', '2', 'c', 'd', 'class="shaded">a</span']
# Arc 'prt': Examples -> ['>']

# %% [markdown]
# ## Save to csv file (filtering)

# %%
import json
import csv
import spacy
from nltk.corpus import wordnet, stopwords
import nltk
import re
import os

# 데이터 병합

# Ensure that you have downloaded wordnet and stopwords data
# nltk.download("wordnet")
# nltk.download("stopwords")

# Load the English NLP model
nlp = spacy.load("en_core_web_sm")

# Load stop words from NLTK
stop_words = set(stopwords.words("english"))

def is_real_word(word, tag):
    # Clean the word by removing punctuation and stripping whitespace
    word_cleaned = re.sub(r'[^\w\s]', '', word.lower()).strip()
    
    # Check if the word is a stop word, too short, or a proper noun
    if word_cleaned in stop_words or len(word_cleaned) < 3 or tag in ["NNP", "NNPS"]:
        return True  # Treat as "real word" to skip adding to not_words list
    
    # Check if the cleaned word exists in WordNet
    return wordnet.synsets(word_cleaned)

def extract_not_words_from_sentences(sentences):
    not_words = []
    
    for sentence in sentences:
        doc = nlp(sentence)
        for token in doc:
            # Identify the "word" token in the structure "X is not a word"
            if token.text.lower() == "word" and token.dep_ == "attr":   # 문장이 바뀔때 수정해야함
                # Check if "is" exists as an auxiliary verb right before "not"
                if token.head.text.lower() == "is" and any(child.text.lower() == "not" for child in token.head.children):
                    # Identify "X" as the token immediately before "is"
                    is_token_index = token.head.i
                    if is_token_index > 0:
                        x_token = doc[is_token_index - 1]
                        x_word = x_token.text

                        has_right_arcs = any(child.i > token.i for child in token.children)

                        # Only apply basic checks for WordNet existence and stop words
                        if not has_right_arcs and not is_real_word(x_word, x_token.tag_):
                            print(f"Adding '{x_word}' to not_words list.")
                            not_words.append((x_word, sentence))  # Save the word along with the original sentence
                        else:
                            print(f"Skipping '{x_word}' (exists in WordNet, is a common word/stop word, or is a proper noun).")
    
    return not_words

def load_existing_csv(filename):
    existing_data = []
    if os.path.exists(filename):
        with open(filename, mode="r") as file:
            reader = csv.reader(file)
            next(reader)  # Skip header
            existing_data = [(row[1], row[2]) for row in reader]  # Only 'Not Word' and 'Original Sentence'
    return existing_data

def save_not_words_to_csv(not_words, filename="/home/work/jupyter/minwoo/CMU/LLM_blocking/data/is_a_made_up_words.csv"):
    with open(filename, mode="w", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(["ID", "Not Word", "Original Sentence"])  # Write header with three columns
        for idx, (word, sentence) in enumerate(not_words, start=1):
            writer.writerow([idx, word, sentence])  # Write each row with ID, word, and original sentence

# 기존 CSV 파일에서 데이터 로드
output_csv_path = "/home/work/jupyter/minwoo/CMU/LLM_blocking/data/is_not_a_words.csv"
existing_data = load_existing_csv(output_csv_path)

# 새로운 JSON 파일에서 데이터 추출
input_file_path = "/home/work/jupyter/minwoo/CMU/LLM_blocking/data/complete_sentence/is_a_made_up_complete_sentence.json"
with open(input_file_path, 'r') as file:
    sentences = json.load(file)
new_not_words = extract_not_words_from_sentences(sentences)

# 기존 데이터와 새로운 데이터 병합
all_not_words = existing_data + new_not_words

# 병합된 데이터를 CSV 파일에 저장
save_not_words_to_csv(all_not_words, output_csv_path)
print(f"Not words updated and saved to {output_csv_path}")
# Out:
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'This' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'Porculent' to not_words list.
# Adding 'youse' to not_words list.
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Festuche' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ''' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '’' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Jenny' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '’' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '’' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'knowledge' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'character' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ',' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'efficate' to not_words list.
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'til' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Lazy' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'REPNECK' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ''' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'unpause' to not_words list.
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'suckitude' to not_words list.
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'result' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ''' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Wokescold' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'GAMMing' to not_words list.
# Adding 'uninnovative' to not_words list.
# Skipping 'It' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'writerly' to not_words list.
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'these' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'itself' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'severities' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'CentriPedal' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'It' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'mambí' to not_words list.
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Ah' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'It' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'thespianism' to not_words list.
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'That' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Veloster' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'smooshing' to not_words list.
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'awesomer' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'ish' to not_words list.
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Surber' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '*' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'numericality' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Haüs' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'ey' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'bigotocracy' to not_words list.
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'initWithFormat:@"%@' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'awesomer' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'or' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Raca' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'sure' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Toodle' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'gigaprofits' to not_words list.
# Skipping 'Winnipeg' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '死前' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'irregardless' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Verticalization' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Christianist' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'ze' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'dom' to not_words list.
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'headline' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'space' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'boringer' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '’' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'know' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Disorientated' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'This' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'This' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Unregular' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'apparently' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Metahuman' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '’' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'funnest' to not_words list.
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ',' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Misseetto' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'journaling' to not_words list.
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'immingle' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'friend' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'acronym' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Declas' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'nomenclated' to not_words list.
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '’' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'weenis' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'This' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'title' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'yup' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'clitarotis' to not_words list.
# Adding 'Cakeage' to not_words list.
# Skipping 'word' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'That' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '’' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'It' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'uncycle' to not_words list.
# Skipping ''' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'n't' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'she' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '155' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'hortitorture' to not_words list.
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ',' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'salesy' to not_words list.
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'approvers' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'terrarial' to not_words list.
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '}' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ',' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'enterable' to not_words list.
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Seniority' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'sth' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'confessionalism' to not_words list.
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'funner' to not_words list.
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Thinlings' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'itself' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'apparently' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Transfering' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Christianphobia' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'blogosphere' to not_words list.
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'Scientism' to not_words list.
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'Weebly' to not_words list.
# Adding 'prac' to not_words list.
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'That' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'learnings' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Anyways' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'Pharfruminsain' to not_words list.
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Ownable' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ',' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'It' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '‘' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'awesomer' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ')' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '’' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Lingua' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'This' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'y' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'presencing' to not_words list.
# Skipping 'edutainment' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'word(which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'It' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ',' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'word' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Mansplaining' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'Irrespectable' to not_words list.
# Adding 'jackassiness' to not_words list.
# Skipping 'ish' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'n’t' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'pooh' to not_words list.
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'MOG' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'answer' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ')' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Persons' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'sasquatchian' to not_words list.
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'AUTHOR_X' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'pansify' to not_words list.
# Skipping 'numetal' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'Smartful' to not_words list.
# Adding 'pseudohomophone' to not_words list.
# Skipping 'Cisgender' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'words' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ')' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Simplisation' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'Ingenuine' to not_words list.
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'racism' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Awoken' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'post' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Xworder' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'This' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'stupider' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'literaryness' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ''' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'ridiculosity' to not_words list.
# Skipping 'NAM' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'judgie' to not_words list.
# Skipping 'This' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'factoid' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'incrementality' to not_words list.
# Adding 'SPAZZFRICA' to not_words list.
# Skipping 'educated' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'typa' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'ABUBBLE' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'flustrating' to not_words list.
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'bakebook' to not_words list.
# Skipping 'ose²' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'ize' to not_words list.
# Skipping 'Torcon' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Ahahahaha' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'WordPress' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Dazs' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'ified' to not_words list.
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'and' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'curriness' to not_words list.
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'hecticness' to not_words list.
# Skipping 'This' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'result' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Disinformation' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'electibility' to not_words list.
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'cuteness' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'often' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '’' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Fullz' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'muhhaaha' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'cuby' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Krocsyldiphithic' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'puhleez' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'argues' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Aaargghhh' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'irregardless' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '’' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ',' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'It' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'irregardless' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'guess' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'mark' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'pay' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'name' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ''' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'epically' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'ish' to not_words list.
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'Viewability' to not_words list.
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'ain't' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'scrabby' to not_words list.
# Adding 'gratituding' to not_words list.
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ';' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'JMRidgeway' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Detachabled' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'deconfirm' to not_words list.
# Adding 'undelete' to not_words list.
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'Ingenuine' to not_words list.
# Skipping 'transmittable' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'enter' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Ah' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'It' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'alphabetized' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '`' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'uncomplicating' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '鯉人' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'mansplaining' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ''' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'tubbing' to not_words list.
# Adding 'alongsider' to not_words list.
# Skipping 'This' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'It' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Hypermediocrity' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Sydegt' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'these' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Majestical' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ',' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '’' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'impactful' to not_words list.
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Curated' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ',' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'impactful' to not_words list.
# Skipping 'way' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'worser' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Cis' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'and' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'word' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Beautifull' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'enjambing' to not_words list.
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'That' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Ssn' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'closure' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'there' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'hobbknocker' to not_words list.
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'inamountable' to not_words list.
# Skipping 'Misleadable' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Kwazzy' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'pompitous' to not_words list.
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Anyways' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'squidlicious' to not_words list.
# Skipping ',' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'name' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'This' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Procrastinational' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'jashoku' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'Corvink' to not_words list.
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'moniker' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'Enturbulated' to not_words list.
# Skipping ''' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ''' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'schloogey' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'QIS' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'dumbfoundedly' to not_words list.
# Skipping 'know' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Pubicular' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'It' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'numericality' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'brang' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'decompisition' to not_words list.
# Adding 'forumship' to not_words list.
# Skipping 'probably' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'aware' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'weirded' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'opinion' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'prolonginator' to not_words list.
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'fourty' to not_words list.
# Adding 'jewelly' to not_words list.
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'apparently' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'course' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'frappacino' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ''s' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'Triaglycerol' to not_words list.
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'Awesomeness' to not_words list.
# Skipping ''' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'UMspielen' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'gram' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Franticness' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'âfunnerâ' to not_words list.
# Skipping 'acknowledge' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'schmage' to not_words list.
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'undazzled' to not_words list.
# Skipping ')' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ',' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# ...
# Skipping ',' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'TCBY'd' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'neutral' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'CentriPedal' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ''' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'y' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'also' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'tubbing' to not_words list.
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Distracter' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'Imput' to not_words list.
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'refudiate' to not_words list.
# Skipping 'TUPNI' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'This' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'zaggy' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Chimping' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Throni' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'ያልተዘመረለት' to not_words list.
# Adding 'purpletrator' to not_words list.
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'Viewability' to not_words list.
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'Corvink' to not_words list.
# Skipping 'Douchebag' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Christmassiest' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'name' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'produced' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Pathing' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'This' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'flundering' to not_words list.
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ''' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'know' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'intelligeranima' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ',' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Squonch' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'Lept' to not_words list.
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '—' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'Äro' to not_words list.
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Alot' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'interoperator' to not_words list.
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'sexytall' to not_words list.
# Skipping ',' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'This' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Hunden' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'lineaged' to not_words list.
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'curmudge' to not_words list.
# Skipping '’' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'ingenuine' to not_words list.
# Adding 'Invigoratory' to not_words list.
# Skipping 'know' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Cinematist' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'insists' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'sandable' to not_words list.
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'nubbly' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'clientize' to not_words list.
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'devolution' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ',' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'word' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'W' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'password' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'It' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Irregardless' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'inamountable' to not_words list.
# Skipping 'fudgy' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'actiony' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '’' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ',' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'me' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'alot' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'It' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'these' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '"' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Prinzicke' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'one' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'annihilation' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'This' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'librarianing' to not_words list.
# Adding 'foldy' to not_words list.
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'mordain' to not_words list.
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'This' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '}' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'Moddable' to not_words list.
# Skipping 'mythical' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Jabberwock' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ''' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ',' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'sure' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Housie' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding 'geeek' to not_words list.
# Skipping 'this' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '’' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '’' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Adding '因果律星' to not_words list.
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Oprahesque' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'which' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'This' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping '”' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'that' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'Pikpik' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping ',' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'password' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Skipping 'it' (exists in WordNet, is a common word/stop word, or is a proper noun).
# Not words updated and saved to /home/work/jupyter/minwoo/CMU/LLM_blocking/data/is_not_a_words.csv

# %% [markdown]
# ## Remove duplicated word

# %%
import pandas as pd

# CSV 파일 경로 설정
csv_file_path = "/home/work/jupyter/minwoo/CMU/LLM_blocking/data/is_not_a_words.csv"

# CSV 파일 읽기
df = pd.read_csv(csv_file_path)

# 'Not Word' 컬럼의 값을 소문자로 변환하여 중복 제거 (첫 번째 값만 남김)
df = df.drop_duplicates(subset=df['Not Word'].str.lower(), keep='first')

# 중복이 제거된 데이터프레임을 CSV 파일에 다시 저장
df.to_csv(csv_file_path, index=False)
print(f"Duplicates removed and saved to {csv_file_path}")

# %% [markdown]
# ## Check the file

# %%
import pandas as pd

# Define the path to the CSV file
csv_file_path = "/home/work/jupyter/minwoo/CMU/LLM_blocking/data/not_words.csv"

# Load the CSV file into a DataFrame
not_words_df = pd.read_csv(csv_file_path)

# Display the DataFrame
not_words_df[:20]
# Out:
#     ID        Not Word
# 0    1       Aprecious
# 1    2       bithought
# 2    3       steroidic
# 3    4        meltaway
# 4    5         Ficking
# 5    6     Counterment
# 6    7           Oodle
# 7    8  collectivities
# 8    9         thrival
# 9   10         unspeak
# 10  11      supposably
# 11  12            alot
# 12  13        thereoff
# 13  14            Alot
# 14  15           cyber
# 15  16    gorgeoussity
# 16  17          vocaba
# 17  18            obvs
# 18  19      supposably
# 19  20       Aprecious

# %%
import pandas as pd
from hunspell import HunSpell
import Levenshtein

h = HunSpell('/usr/share/hunspell/en_US.dic', '/usr/share/hunspell/en_US.aff')

file_path = "/home/work/jupyter/minwoo/CMU/LLM_blocking/data/blocking words/blocking_words.csv" # modify your file path

df = pd.read_csv(file_path)


def load_dictionary(dic_path):
    with open(dic_path, 'r') as f:
        return [line.strip() for line in f.readlines() if line.strip()]

dictionary = load_dictionary("/usr/share/hunspell/en_US.dic")

def is_spacing_error(word):
    for i in range(1, len(word)):  
        part1, part2 = word[:i], word[i:]
        if h.spell(part1) and h.spell(part2):  
            return True
    return False

def is_typo_or_spacing_error(word, dictionary, threshold=2):    # threshold
    if is_spacing_error(word):  
        return False
    if h.spell(word):  
        return False
    closest_word, distance = get_closest_word(word, dictionary)
    return distance > threshold  

def get_closest_word(word, dictionary):
    closest_word = min(dictionary, key=lambda x: Levenshtein.distance(word, x))
    distance = Levenshtein.distance(word, closest_word)
    return closest_word, distance

filtered_words = []

for _, row in df.iterrows():
    word = row['Not Word']
    if is_typo_or_spacing_error(word, dictionary):  
        filtered_words.append(row)

filtered_df = pd.DataFrame(filtered_words)

output_path = "/home/work/jupyter/minwoo/CMU/LLM_blocking/data/blocking words/filtered_blocking_words.csv"
filtered_df.to_csv(output_path, index=False)
# Out:
# 문법적으로 틀린 단어만 저장 완료: filtered_grammar_errors.csv
